# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv(r"C:\Users\HP\cardio_train.csv" ,sep=';' )
df=df.drop(['id'],axis=1)
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 69995     0       1       0
# 69996     0       1       1
# 69997     1       0       1
# 69998     0       0       1
# 69999     0       1       0
#
# [70000 rows x 12 columns]

# %%
df.corr().round(2)
# Out:
#               age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# age          1.00   -0.02   -0.08    0.05   0.02   0.02         0.15  0.10
# gender      -0.02    1.00    0.50    0.16   0.01   0.02        -0.04 -0.02
# height      -0.08    0.50    1.00    0.29   0.01   0.01        -0.05 -0.02
# weight       0.05    0.16    0.29    1.00   0.03   0.04         0.14  0.11
# ap_hi        0.02    0.01    0.01    0.03   1.00   0.02         0.02  0.01
# ap_lo        0.02    0.02    0.01    0.04   0.02   1.00         0.02  0.01
# cholesterol  0.15   -0.04   -0.05    0.14   0.02   0.02         1.00  0.45
# gluc         0.10   -0.02   -0.02    0.11   0.01   0.01         0.45  1.00
# smoke       -0.05    0.34    0.19    0.07  -0.00   0.01         0.01 -0.00
# alco        -0.03    0.17    0.09    0.07   0.00   0.01         0.04  0.01
# active      -0.01    0.01   -0.01   -0.02  -0.00   0.00         0.01 -0.01
# cardio       0.24    0.01   -0.01    0.18   0.05   0.07         0.22  0.09
#
#              smoke  alco  active  cardio
# age          -0.05 -0.03   -0.01    0.24
# gender        0.34  0.17    0.01    0.01
# height        0.19  0.09   -0.01   -0.01
# weight        0.07  0.07   -0.02    0.18
# ap_hi        -0.00  0.00   -0.00    0.05
# ap_lo         0.01  0.01    0.00    0.07
# cholesterol   0.01  0.04    0.01    0.22
# gluc         -0.00  0.01   -0.01    0.09
# smoke         1.00  0.34    0.03   -0.02
# alco          0.34  1.00    0.03   -0.01
# active        0.03  0.03    1.00   -0.04
# cardio       -0.02 -0.01   -0.04    1.00

# %%
sns.heatmap(df.corr().round(2))
# Out:
# <Axes: >
